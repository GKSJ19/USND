# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\RISHI\Desktop\USND\notebooks\datasets.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46185 entries, 0 to 46184
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   declarationNumber                46185 non-null  object
#  1   declarationType                  46185 non-null  object
#  2   declarationDate                  46185 non-null  object
#  3   state                            46185 non-null  object
#  4   county                           45988 non-null  object
#  5   incidentType                     46185 non-null  object
#  6   incidentTitle                    46185 non-null  object
#  7   startDate                        46185 non-null  object
#  8   endDate                          45843 non-null  object
#  9   closeDate                        35210 non-null  object
#  10  individualAssistanceProgram      46185 non-null  object
#  11  individualsAndHouseholdsProgram  46185 non-null  object
# ...

# %%
df = df.rename(columns={
    'Declaration Number': 'declarationNumber',
    'Declaration Type': 'declarationType',
    'Declaration Date': 'declarationDate',
    'State': 'state',
    'County': 'county',
    'Disaster Type': 'incidentType',
    'Disaster Title': 'incidentTitle',
    'Start Date': 'startDate',
    'End Date': 'endDate',
    'Close Date': 'closeDate',
    'Individual Assistance Program': 'individualAssistanceProgram',
    'Individuals & Households Program': 'individualsAndHouseholdsProgram',
    'Public Assistance Program': 'publicAssistanceProgram',
    'Hazard Mitigation Program': 'hazardMitigationProgram'
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46185 entries, 0 to 46184
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   declarationNumber                46185 non-null  object
#  1   declarationType                  46185 non-null  object
#  2   declarationDate                  46185 non-null  object
#  3   state                            46185 non-null  object
#  4   county                           45988 non-null  object
#  5   incidentType                     46185 non-null  object
#  6   incidentTitle                    46185 non-null  object
#  7   startDate                        46185 non-null  object
#  8   endDate                          45843 non-null  object
#  9   closeDate                        35210 non-null  object
#  10  individualAssistanceProgram      46185 non-null  object
#  11  individualsAndHouseholdsProgram  46185 non-null  object
# ...

# %%
# 1. Convert declarationDate to a datetime object 
df['declarationDate'] = pd.to_datetime(df['declarationDate'])

# 2. Extract Year and Month (Required for Milestone 3) [cite: 26, 27]
df['year'] = df['declarationDate'].dt.year
df['month'] = df['declarationDate'].dt.month

# 3. Standardize State values 
df['state'] = df['state'].astype(str).str.upper().str.strip()

# 4. Check for missing values 
print("Missing values per column:\n", df.isnull().sum())

# 5. Drop rows where critical geographic info is missing 
df = df.dropna(subset=['state', 'incidentType'])
print(f"Dataset covers {df['state'].nunique()} unique states.")
# Out:
# Missing values per column:
#  declarationNumber                      0
# declarationType                        0
# declarationDate                        0
# state                                  0
# county                               197
# incidentType                           0
# incidentTitle                          0
# startDate                              0
# endDate                              342
# closeDate                          10975
# individualAssistanceProgram            0
# individualsAndHouseholdsProgram        0
# publicAssistanceProgram                0
# hazardMitigationProgram                0
# year                                   0
# month                                  0
# dtype: int64
# Dataset covers 59 unique states.

# %%
df.to_csv('datasets.csv', index=False)
